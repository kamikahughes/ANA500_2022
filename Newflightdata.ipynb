# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv (r'C:\Users\Kamika Hughes\OneDrive\ANA500\newflight_data.csv', thousands=",")

print(df)
# Out:
#      Origin Destination    Company Departure Time Arrival Time Duration Time  \
# 0       BOM         DEL    IndiGo            8:30        10:25        1h 55m
# 1       BOM         DEL    IndiGo            7:45         9:50        2h 05m
# 2       BOM         DEL   Vistara           12:25        14:30        2h 05m
# 3       BOM         DEL    IndiGo           10:05        12:15        2h 10m
# 4       BOM         DEL    IndiGo           13:40        15:50        2h 10m
# ...     ...         ...        ...            ...          ...           ...
# 2902    BOM         MAA   Vistara           17:50        19:55        2h 05m
# 2903    BOM         MAA   Vistara           21:00        23:05        2h 05m
# 2904    BOM         MAA    IndiGo           19:30        21:35        2h 05m
# 2905    BOM         MAA  Go First           20:15        22:20        2h 05m
# 2906    BOM         MAA  SpiceJet           19:30        21:20        1h 50m
#
#      Flight Price        Date Cabin Class
# ...

# %%
X = list(df.iloc[:, 1])
Y = list(df.iloc[:, 6])

plt.bar(X, Y, color='b')
plt.xlabel("Destination")
plt.ylabel("Flight Price")
# Out:
# Text(0, 0.5, 'Flight Price')

# %%
df.columns
# Out:
# Index(['Origin', 'Destination', 'Company', 'Departure Time', 'Arrival Time',
#        'Duration Time', 'Flight Price', 'Date', 'Cabin Class'],
#       dtype='object')

# %%
type('Flight Price')
# Out:
# str

# %%
df.describe(include='object')
# Out:
#        Origin Destination  Company Departure Time Arrival Time Duration Time  \
# count    2907        2907     2907           2907         2907          2907
# unique      6           6        6            146          157            23
# top       BOM         BOM  IndiGo            7:00        16:35        2h 10m
# freq     1422        1485      976             90           61           452
#
#        Flight Price        Date Cabin Class
# count          2907        2907        2907
# unique          281          15           1
# top           5,943  22-02-2022     Economy
# freq            100         212        2907

# %%
fig, ax = plt.subplots(2,figsize=(12, 11))
ax[0].scatter(x = df['Departure Time'], y = df['Flight Price'])
ax[0].set_xlabel("Departure Time")
ax[0].set_ylabel("Flight Price")
ax[0].set_title("Price by Departure")

ax[1].scatter(x = df['Arrival Time'], y = df['Flight Price'])
ax[1].set_xlabel("Arrival Time")
ax[1].set_ylabel("Flight Price")
ax[1].set_title("Price by Arrival")
# Out:
# Text(0.5, 1.0, 'Price by Arrival')
